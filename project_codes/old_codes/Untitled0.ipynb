# %%
#file = open("Albedo_Gamma_background_iXRD_ShieldingPhysics_W_theta_0_45_deg_R_90cm_Zenith_0_deg_seed_575841913_16_500_Bins.bin", "rb")
file = open("Albedo_Gamma_background_iXRD_ShieldingPhysics_W_theta_0_45_deg_R_90cm_Zenith_0_deg_seed_575841913_16_500_Bins_Latest.bin", "rb")

counter = 0;

byte = file.read(8)
while byte:
    print(byte)
    byte = file.read(8)
    counter +=1;

    if(counter == 200):
      break

file.close()
