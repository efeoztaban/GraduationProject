# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rnd
import seaborn as sn
import math as math
import time
from prettytable import PrettyTable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/ENS 491 492/tasks/classification/data/data_march
# Out:
# /content/drive/MyDrive/ENS 491 492/tasks/classification/data/data_march

# %%
df_cxb = pd.read_csv("cxb_data.txt", sep=";", header=None)
df_cxb = df_cxb.drop(6,axis=1)
df_cxb.columns = ["Event Number","Cloud Number","X position","Y position","Z position","Energy"]

# %%
df_cxb
# Out:
#           Event Number  Cloud Number  X position  Y position  Z position  \
# 0                    1             0    20.37710     20.4196    0.014218
# 1                    1             1    20.37720     20.4196    0.014250
# 2                    1             2    20.37710     20.4196    0.014218
# 3                    1             3    20.37710     20.4196    0.014218
# 4                    1             4    20.37710     20.4196    0.014218
# ...                ...           ...         ...         ...         ...
# 74703458       2005921            63     4.18935     19.2219    1.353670
# 74703459       2005921            64     4.18935     19.2219    1.353670
# 74703460       2005921            65     4.18935     19.2219    1.353670
# 74703461       2005921            66     4.18935     19.2219    1.353670
# 74703462       2005921            67     4.18935      0.0000    0.000000
#
#            Energy
# 0         0.20204
# 1         6.65117
# 2         0.03825
# ...

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Z position"].mean())
# Out:
# 3.817706020184658
# 4.496563462739848
# 4.409333651017242
# 3.5997098780740013
# 2.952356400751449
# 2.639876734389349
# 2.593831914496536
# 2.550181200292097
# 2.519154919725733
# 2.522825185598633
# 2.5027210131614166
# 2.555246287874146
# 2.4471900576878483
# 2.5283746919949683
# 2.4837052885045066
# 2.4869807089448592
# 2.478054625616814
# 2.5010453381369477
# 2.482386090881574

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["X position"].mean())
# Out:
# 12.77928418320783
# 12.840401643432058
# 12.649313700797265
# 12.90965714713093
# 12.944540995908019
# 12.552383881096572
# 12.822109596387698
# 12.772704523056477
# 12.64542124974683
# 12.511659871291927
# 12.69230940887267
# 12.673611631553957
# 12.823406761381104
# 12.894356980451644
# 12.723529526832959
# 12.679773362872098
# 12.777198736133538
# 12.73262188294931
# 12.747268494418693

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Y position"].mean())
# Out:
# 13.406672709839482
# 13.120725643690715
# 13.13564696343944
# 13.179230256270326
# 12.926416109789962
# 12.870723480960221
# 13.049174359900201
# 13.079930730060585
# 12.974436657389854
# 12.69300768806945
# 13.042115430889783
# 13.06774738519952
# 13.185590242018975
# 13.286533838160128
# 13.17648391703011
# 13.204710570859593
# 13.305646557099958
# 13.14811751498994
# 13.209678969560592

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Energy"].mean())
# Out:
# 2.128856731406931
# 2.442682678662089
# 2.7171884400917166
# 4.135679886109855
# 5.94873111657124
# 7.41996837776414
# 8.338446756919602
# 9.210958982251968
# 10.178577937896682
# 10.983974930432595
# 12.1274102174369
# 12.912449984990623
# 14.031925019624031
# 14.980509867603413
# 15.877569977567616
# 17.260264770281943
# 18.628335576770628
# 19.687096670445094
# 21.16795725402835

# %%
copy = df_cxb.iloc[:50].copy()

# %%
copy
# Out:
#     Event Number  Cloud Number  X position  Y position  Z position   Energy
# 0              1             0    20.37710    20.41960    0.014218  0.20204
# 1              1             1    20.37720    20.41960    0.014250  6.65117
# 2              1             2    20.37710    20.41960    0.014218  0.03825
# 3              1             3    20.37710    20.41960    0.014218  0.03751
# 4              1             4    20.37710    20.41960    0.014218  0.04280
# 5              1             5    20.37710    20.41960    0.014218  0.02346
# 6              1             6    20.37710    20.41960    0.014217  0.26245
# 7              1             7    20.37710    20.41960    0.014218  0.28899
# 8              1             8    20.37710    20.41960    0.014218  0.03751
# 9              1             9    20.37710    20.41950    0.014214  2.70248
# 10             1            10    20.37710    20.41960    0.014220  0.38651
# ...

# %%
ids = copy["Event Number"].unique()
rnd.shuffle(ids)
df = copy.set_index("Event Number").loc[ids].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a2ea1d2a30ce> in <module>()
# ----> 1 ids = copy["Event Number"].unique()
#       2 rnd.shuffle(ids)
#       3 df = copy.set_index("Event Number").loc[ids].reset_index()
#
# NameError: name 'copy' is not defined

# %%
ids
# Out:
# array([2, 3, 1, 5, 4])

# %%
df
# Out:
#     Event Number  Cloud Number  X position  Y position  Z position   Energy
# 0              2             0    23.10570     7.56675    0.018779  0.18904
# 1              2             1    23.10570     7.56679    0.018743  5.95222
# 2              2             2    23.10570     7.56675    0.018779  0.02242
# 3              2             3    23.10570     7.56675    0.018779  0.03317
# 4              2             4    23.10570     7.56675    0.018779  0.02150
# 5              2             5    23.10570     7.56675    0.018779  0.02303
# 6              2             6    23.10570     7.56675    0.018779  0.02150
# 7              2             7    23.10570     7.56675    0.018779  0.02103
# 8              2             8    23.10570     7.56675    0.018779  0.01381
# 9              2             9    23.10570     7.56675    0.018779  0.03108
# 10             2            10    23.10570     7.56675    0.018779  0.41264
# ...

# %%
ids = df_cxb["Event Number"].unique()
rnd.shuffle(ids)
df_cxb = df_cxb.set_index("Event Number").loc[ids].reset_index()

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["X position"].mean())

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Y position"].mean())

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Z position"].mean())

# %%
for i in range(100000,2000000,100000):
  print(df_cxb.iloc[i-100000:i]["Energy"].mean())
